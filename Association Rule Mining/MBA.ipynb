# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori           # to obtain the products that fulfill the support threshold
from mlxtend.preprocessing import TransactionEncoder    # to encode data before passing in to apriori algorithm
from mlxtend.frequent_patterns import association_rules # to get the association rules

dat = pd.read_csv('website_link.csv')
dat = dat.drop(columns = ['Unnamed: 0'])   # drop redundant column

# %%
# Getting the unique id for each of the url
alist = []             # contains all the unique url
unique_id = []         # contains the index of the urls in alist
for i in range(len(dat['links'])):
    url = dat['links'][i].replace(" ", "")        # to remove all the blank space in url
    if str(url) not in alist:                     # if-else statement to check if url already appended
        alist.append(str(url))
        unique_id.append(len(alist)-1)
    else:
        val = alist.index(str(url))
        unique_id.append(val)
        
df_id = pd.DataFrame({'id': unique_id})
df = pd.concat([dat, df_id], axis= 1)   # attach the unique id for column 'links'
df.tail(10)
# Out:
#                                                    links  \
# 48664   http://www.amazon.co.uk/Star-Wars-Costume-Sto...
# 48665   http://www.amazon.co.uk/Rubies-Costume-Star-W...
# 48666    http://www.amazon.co.uk/STAR-WARS-Stormtrooper
# 48667        http://www.amazon.co.uk/Deluxe-Stormtrooper
# 48668  http://www.amazon.co.uk/Bandai-Star-Wars-Fight...
# 48669   http://www.amazon.co.uk/Bandai-Star-Wars-Star...
# 48670   http://www.amazon.co.uk/Star-Wars-48-Snow-Spe...
# 48671   http://www.amazon.co.uk/Bandai-Advanced-Starf...
# 48672   http://www.amazon.co.uk/Star-Wars-fighter-res...
# 48673                 http://www.amazon.co.uk/Millennium
#
#                                                  product     id
# 48664  Star Wars Costume, Kids Stormtrooper Costume S...  28287
# 48665  Star Wars Costume, Kids Stormtrooper Costume S...  28288
# 48666  Star Wars Costume, Kids Stormtrooper Costume S...  28289
# 48667  Star Wars Costume, Kids Stormtrooper Costume S...  10801
# 48668                  Star Wars 1/72 Y-Wing Starfighter  28290
# 48669                  Star Wars 1/72 Y-Wing Starfighter  28291
# 48670                  Star Wars 1/72 Y-Wing Starfighter  28292
# 48671                  Star Wars 1/72 Y-Wing Starfighter  28293
# 48672                  Star Wars 1/72 Y-Wing Starfighter  28294
# 48673                  Star Wars 1/72 Y-Wing Starfighter   3455

# %%
# convert elements of series to string object
df['id'] = df['id'].apply(str)

# %%
# Same product concatenate it into one record, required format for apriori
new_df = df[['product', 'id']].groupby(['product']).transform(lambda x: ','.join(x))
new_df['product'] = df['product']         # attach product according to new dataframe

# %%
# Drop all the rows with duplicate values
new_df.drop_duplicates(subset='id', inplace=True)     # id contains concatenated id
new_df.reset_index(drop=True, inplace=True)
print(len(new_df))                                    # to make sure the result is as expected
# Out:
# 8711

# %%
# Rename the column
new_df.rename(columns={'id': "linked_prod_list"}, inplace=True)

# %%
# Rearrange the format into list
for t in range(len(new_df)):
    result = new_df['linked_prod_list'][t].split(",")
    new_df['linked_prod_list'][t] = result

new_df.head(10)
# Out:
#            linked_prod_list                                            product
# 0        [0, 1, 2, 3, 4, 5]                              Hornby 2014 Catalogue
# 1      [6, 7, 8, 9, 10, 11]  FunkyBuys® Large Christmas Holiday Express Fes...
# 2  [12, 13, 14, 15, 16, 17]  CLASSIC TOY TRAIN SET TRACK CARRIAGES LIGHT EN...
# 3  [18, 19, 20, 21, 22, 23]  Hornby 00 Gauge 0-4-0 Gildenlow Salt Co. Steam...
# 4      [24, 25, 26, 27, 28]  20pcs Model Garden Light Double Heads Lamppost...
# 5                  [29, 30]  Hornby 00 Gauge 230mm BR Bogie Passenger Brake...
# 6  [31, 20, 23, 32, 33, 34]                   Hornby Santa's Express Train Set
# 7   [35, 4, 36, 37, 38, 39]  Hornby Gauge Western Express Digital Train Set...
# 8          [40, 41, 40, 42]  Learning Curve Chuggington Interactive Chatsworth
# 9  [43, 20, 44, 45, 46, 47]  Hornby Gauge Railroad Mosley Tarmacadam Locomo...

# %%
# Pass the url represented by unique IDs into the apriori algorithm
# Encode the data into a sparse dataframe
te = TransactionEncoder()
te_array = te.fit(new_df['linked_prod_list']).transform(new_df['linked_prod_list'], sparse=True)
convert = pd.SparseDataFrame(te_array, columns=te.columns_, default_fill_value=False)

# %%
# Apriori algorithm to obtain the frequent itemset
freq_itemsets = apriori(convert, min_support=0.001, use_colnames= True)
freq_itemsets['length'] = freq_itemsets['itemsets'].apply(lambda x: len(x))
freq_itemsets
# Out:
#       support                  itemsets  length
# 0    0.001148                     (103)       1
# 1    0.004362                    (1038)       1
# 2    0.002181                    (1040)       1
# 3    0.001378                    (1044)       1
# 4    0.001263                   (10668)       1
# 5    0.001033                   (11087)       1
# 6    0.001033                    (1125)       1
# 7    0.001263                   (11266)       1
# 8    0.001722                   (11314)       1
# 9    0.001148                   (11336)       1
# 10   0.001263                   (11339)       1
# 11   0.001033                   (11387)       1
# 12   0.001378                    (1160)       1
# 13   0.015957                    (1238)       1
# 14   0.017220                    (1265)       1
# 15   0.002411                   (12811)       1
# 16   0.001263                   (12813)       1
# 17   0.001148                   (12825)       1
# 18   0.001378                   (12826)       1
# 19   0.001722                   (12827)       1
# 20   0.001492                   (12828)       1
# 21   0.001148                   (12864)       1
# 22   0.001033                   (12868)       1
# 23   0.001033                   (12890)       1
# 24   0.005625                    (1300)       1
# 25   0.002870                    (1301)       1
# 26   0.001033                   (13019)       1
# 27   0.001378                    (1302)       1
# 28   0.003559                    (1303)       1
# 29   0.004133                    (1304)       1
# ..        ...                       ...     ...
# 306  0.001033            (14507, 14564)       2
# 307  0.001033            (14522, 14517)       2
# 308  0.001033            (14594, 14564)       2
# 309  0.001148              (1489, 1492)       2
# 310  0.001033              (1491, 1492)       2
# 311  0.001033            (16895, 16896)       2
# 312  0.001263            (16951, 16911)       2
# 313  0.001033              (1864, 1865)       2
# 314  0.001492                  (43, 20)       2
# 315  0.001263            (25250, 25267)       2
# 316  0.001033            (25577, 25584)       2
# 317  0.001148            (25615, 25614)       2
# 318  0.001148              (3782, 3783)       2
# 319  0.001263              (3929, 3834)       2
# 320  0.001148              (5190, 5281)       2
# 321  0.001263              (6063, 6062)       2
# 322  0.001263              (6063, 6075)       2
# 323  0.001263              (6063, 6083)       2
# 324  0.001148              (6063, 6094)       2
# 325  0.001722              (8252, 8250)       2
# 326  0.001263              (8401, 8250)       2
# 327  0.001607        (1301, 1300, 1303)       3
# 328  0.002066        (1304, 1300, 1301)       3
# 329  0.001148        (1300, 1302, 1303)       3
# 330  0.001263        (1304, 1300, 1302)       3
# 331  0.002755        (1304, 1300, 1303)       3
# 332  0.001492        (1301, 1304, 1303)       3
# 333  0.001148        (1304, 1302, 1303)       3
# 334  0.001492  (1301, 1300, 1303, 1304)       4
# 335  0.001148  (1304, 1300, 1302, 1303)       4
#
# [336 rows x 3 columns]

# %%
# Obtain the rules that fulfills the confidence threshold
rules = association_rules(freq_itemsets, metric="confidence", min_threshold = 0.8)
rules
# Out:
#            antecedents         consequents  antecedent support  \
# 0               (1301)              (1300)            0.002870
# 1               (1302)              (1300)            0.001378
# 2               (1303)              (1300)            0.003559
# 3               (1304)              (1300)            0.004133
# 4               (1302)              (1303)            0.001378
# 5               (1302)              (1304)            0.001378
# 6               (1303)              (1304)            0.003559
# 7               (1507)              (1353)            0.001263
# 8              (14564)             (14507)            0.001263
# 9              (14522)             (14517)            0.001148
# 10             (14594)             (14564)            0.001148
# 11             (14564)             (14594)            0.001263
# 12              (1489)              (1492)            0.001263
# 13              (1491)              (1492)            0.001148
# 14             (16896)             (16895)            0.001148
# 15              (1865)              (1864)            0.001148
# 16                (43)                (20)            0.001607
# 17             (25267)             (25250)            0.001378
# 18             (25614)             (25615)            0.001378
# 19              (3782)              (3783)            0.001148
# 20              (3783)              (3782)            0.001263
# 21              (6062)              (6063)            0.001263
# 22              (6083)              (6063)            0.001378
# 23              (6094)              (6063)            0.001148
# 24        (1301, 1303)              (1300)            0.001722
# 25        (1304, 1301)              (1300)            0.002066
# 26        (1300, 1301)              (1304)            0.002411
# 27        (1300, 1302)              (1303)            0.001378
# 28        (1302, 1303)              (1300)            0.001148
# 29              (1302)        (1300, 1303)            0.001378
# 30        (1304, 1302)              (1300)            0.001263
# 31        (1300, 1302)              (1304)            0.001378
# 32              (1302)        (1304, 1300)            0.001378
# 33        (1304, 1303)              (1300)            0.002870
# 34        (1300, 1303)              (1304)            0.003214
# 35        (1301, 1303)              (1304)            0.001722
# 36        (1304, 1302)              (1303)            0.001263
# 37        (1302, 1303)              (1304)            0.001148
# 38              (1302)        (1304, 1303)            0.001378
# 39  (1300, 1301, 1303)              (1304)            0.001607
# 40  (1304, 1301, 1303)              (1300)            0.001492
# 41        (1301, 1303)        (1304, 1300)            0.001722
# 42  (1304, 1300, 1302)              (1303)            0.001263
# 43  (1304, 1302, 1303)              (1300)            0.001148
# 44  (1300, 1302, 1303)              (1304)            0.001148
# 45        (1304, 1302)        (1300, 1303)            0.001263
# 46        (1300, 1302)        (1304, 1303)            0.001378
# 47        (1302, 1303)        (1304, 1300)            0.001148
# 48              (1302)  (1304, 1300, 1303)            0.001378
#
#     consequent support   support  confidence        lift  leverage  conviction
# 0             0.005625  0.002411    0.840000  149.331429  0.002395    6.214843
# 1             0.005625  0.001378    1.000000  177.775510  0.001370         inf
# 2             0.005625  0.003214    0.903226  160.571429  0.003194   10.275208
# 3             0.005625  0.003788    0.916667  162.960884  0.003765   11.932499
# 4             0.003559  0.001148    0.833333  234.166667  0.001143    5.978648
# 5             0.004133  0.001263    0.916667  221.807870  0.001257   11.950408
# 6             0.004133  0.002870    0.806452  195.138889  0.002855    5.145314
# 7             0.002181  0.001148    0.909091  416.794258  0.001145   10.976007
# 8             0.001607  0.001033    0.818182  509.084416  0.001031    5.491161
# 9             0.001607  0.001033    0.900000  559.992857  0.001031    9.983928
# 10            0.001263  0.001033    0.900000  712.718182  0.001032    9.987372
# 11            0.001148  0.001033    0.818182  712.718182  0.001032    5.493686
# 12            0.001952  0.001148    0.909091  465.828877  0.001146   10.978533
# 13            0.001952  0.001033    0.900000  461.170588  0.001031    9.980484
# 14            0.001492  0.001033    0.900000  603.069231  0.001031    9.985076
# 15            0.001492  0.001033    0.900000  603.069231  0.001031    9.985076
# 16            0.001952  0.001492    0.928571  475.810924  0.001489   13.972678
# 17            0.002526  0.001263    0.916667  362.958333  0.001259   11.969693
# 18            0.001607  0.001148    0.833333  518.511905  0.001146    5.990357
# 19            0.001263  0.001148    1.000000  791.909091  0.001147         inf
# 20            0.001148  0.001148    0.909091  791.909091  0.001147   10.987372
# 21            0.003100  0.001263    1.000000  322.629630  0.001259         inf
# 22            0.003100  0.001263    0.916667  295.743827  0.001259   11.962806
# 23            0.003100  0.001148    1.000000  322.629630  0.001144         inf
# 24            0.005625  0.001607    0.933333  165.923810  0.001597   14.915624
# 25            0.005625  0.002066    1.000000  177.775510  0.002055         inf
# 26            0.004133  0.002066    0.857143  207.404762  0.002056    6.971071
# 27            0.003559  0.001148    0.833333  234.166667  0.001143    5.978648
# 28            0.005625  0.001148    1.000000  177.775510  0.001142         inf
# 29            0.003214  0.001148    0.833333  259.255952  0.001144    5.980714
# 30            0.005625  0.001263    1.000000  177.775510  0.001256         inf
# 31            0.004133  0.001263    0.916667  221.807870  0.001257   11.950408
# 32            0.003788  0.001263    0.916667  241.972222  0.001258   11.954540
# 33            0.005625  0.002755    0.960000  170.664490  0.002739   24.859373
# 34            0.004133  0.002755    0.857143  207.404762  0.002742    6.971071
# 35            0.004133  0.001492    0.866667  209.709259  0.001485    7.469005
# 36            0.003559  0.001148    0.909091  255.454545  0.001143   10.960854
# 37            0.004133  0.001148    1.000000  241.972222  0.001143         inf
# 38            0.002870  0.001148    0.833333  290.366667  0.001144    5.982780
# 39            0.004133  0.001492    0.928571  224.688492  0.001486   13.942142
# 40            0.005625  0.001492    1.000000  177.775510  0.001484         inf
# 41            0.003788  0.001492    0.866667  228.773737  0.001486    7.471588
# 42            0.003559  0.001148    0.909091  255.454545  0.001143   10.960854
# 43            0.005625  0.001148    1.000000  177.775510  0.001142         inf
# 44            0.004133  0.001148    1.000000  241.972222  0.001143         inf
# 45            0.003214  0.001148    0.909091  282.824675  0.001144   10.964642
# 46            0.002870  0.001148    0.833333  290.366667  0.001144    5.982780
# 47            0.003788  0.001148    1.000000  263.969697  0.001144         inf
# 48            0.002755  0.001148    0.833333  302.465278  0.001144    5.983469

# %%
# Get the important information into a dataframe for further processing
rules_ant = pd.DataFrame({'antecedents': rules['antecedents']})
rules_con = pd.DataFrame({'consequents': rules['consequents']})
rules_support = pd.DataFrame({'support': rules['support']})
rules_conf = pd.DataFrame({'confidence': rules['confidence']})
df_rules = pd.concat([rules_ant, rules_con,rules_support, rules_conf], axis= 1)

# %%
# Loop through both 'antecedents' and 'consquents' column to get the list of unique ids in the rules
new_list = []
for i in df_rules['antecedents'].unique():
    x = i
    string = ""
    for t in x:
        if len(string) < 4:
            string += t
    if string not in new_list:
        new_list.append(string)
        
for j in df_rules['consequents'].unique():
    x = j
    string = ""
    for t in x:
        if len(string) < 4:
            string += t
    if string not in new_list:
        new_list.append(string)

print(new_list)
# Out:
# ['1301', '1302', '1303', '1304', '1507', '14564', '14522', '14594', '1489', '1491', '16896', '1865', '43', '25267', '25614', '3782', '3783', '6062', '6083', '6094', '1300', '1353', '14507', '14517', '1492', '16895', '1864', '20', '25250', '25615', '6063']

# %%
# Based on the unique ids, get the associated urls 
url_list = []
for i in new_list:
    val = int(i)
    url_list.append(alist[val])   # alist contains the urls, can be access through the index value

# %%
# Requests for the product name through web scraping
import requests                           # library to make request, necessary for web scraping
from bs4 import BeautifulSoup             # library for pulling data out of HTML and XML files.
import time

def get_product(url):
    """
    This function is to configure and send request to the server based on each url
    :param url: website link where web scraping is done
    :returns: return the paragraph that contains the desired result
    """
    time.sleep(2)   # to avoid being recognize as spam
    with requests.Session() as res:
        headers = {"User-Agent": 'Mozilla/5.0 (Windows NT 6.2; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36'}
        response = res.get(url, timeout=5, headers = headers)               # timeout if it takes more than 5 seconds
    soup = BeautifulSoup(response.text, "html.parser")
    if response.status_code == requests.codes.ok:
        result = soup.find('title')
        return result
    else:
        if response.status_code == '503':
            return

def proc_result(result):
    """
    This function is mainly to process the response obtained
    :param result: the input is the result extracted from the response of the request
    :returns: None if there is no result and product name if there is a response
    """
    if result == None:
        return 
    else:
        string = ''
        removed = result.text.strip()
        name = removed.split(":")
        string += name[0]
        if name[1] == ' Amazon.co.uk':   # to make sure that it takes the entire product name
            return name[0]
        else:
            string += name[1]            # to avoid getting only part of the product name
            return string
        
prod = []
for i in range(len(url_list)):
    result = get_product(url_list[i])
    if result != 'Robot Check':
        prod_name = proc_result(result)
        prod.append(prod_name)
    else:
        assert result == 'Robot Check',"Robot Check error encountered"

# %%
# Get the item in frozenset into a list, for easy access
df_rules['ant_list'] = np.nan
df_rules['cons_list'] = np.nan
for k in range(len(df_rules['antecedents'])):
    x = df_rules['antecedents'][k]
    string = ""
    temp = []
    for t in x:
        if len(string) < 4:
            string += t
        else:
            string = ""
            string += t
        
        temp.append(string)
    df_rules['ant_list'][k] = temp
    
for j in range(len(df_rules['consequents'])):
    x = df_rules['consequents'][j]
    string = ""
    temp = []
    for t in x:
        if len(string) < 4:
            string += t
        else:
            string = ""
            string += t
        
        temp.append(string)
    df_rules['cons_list'][j] = temp
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Get the product name for each of the unique id and assign it into their respective row
df_rules['ant_prodName'] = np.nan
df_rules['con_prodName'] = np.nan
for t in range(len(df_rules['ant_list'])):
    if len(df_rules['ant_list'][t]) >= 2:       # if there are more than one product, create a list
        temp = []
        for j in df_rules['ant_list'][t]: 
            val = new_list.index(str(j))
            prod_name = prod[val]
            if prod_name != None:
                temp.append(prod_name)
            else:
                temp.append(np.nan)             # append nan if there is no product name
            df_rules['ant_prodName'][t] = temp
    else:
        for j in df_rules['ant_list'][t]: 
            val = new_list.index(str(j))
            prod_name = prod[val]
            if prod_name != None:
                df_rules['ant_prodName'][t] = prod[val]
            else:
                df_rules['ant_prodName'][t] = np.nan

for t in range(len(df_rules['cons_list'])):
    if len(df_rules['cons_list'][t]) >= 2:      # if there are more than one product, create a list
        temp = []
        for j in df_rules['cons_list'][t]: 
            val = new_list.index(str(j))
            prod_name = prod[val]
            if prod_name != None:
                temp.append(prod_name)
            else:
                temp.append(np.nan)             # append nan if there is no product name
            df_rules['con_prodName'][t] = temp
    else:
        for j in df_rules['cons_list'][t]: 
            val = new_list.index(str(j))
            prod_name = prod[val]
            if prod_name != None:
                df_rules['con_prodName'][t] = prod[val]
            else:
                df_rules['con_prodName'][t] = np.nan
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Drop if the product name is nan, and then sort it in descending order
df_rules = df_rules.dropna(subset=['ant_prodName', 'con_prodName'])
df_rules = df_rules.sort_values(by = ['confidence'], ascending = False)
df_rules.reset_index(drop=True, inplace=True)     # nan product name means wrong website link or item no longer on amazon
df_rules
# Out:
#            antecedents         consequents   support  confidence  \
# 0               (1302)              (1300)  0.001378    1.000000
# 1               (3782)              (3783)  0.001148    1.000000
# 2         (1302, 1303)        (1304, 1300)  0.001148    1.000000
# 3   (1300, 1302, 1303)              (1304)  0.001148    1.000000
# 4   (1304, 1302, 1303)              (1300)  0.001148    1.000000
# 5   (1304, 1301, 1303)              (1300)  0.001492    1.000000
# 6         (1302, 1303)              (1304)  0.001148    1.000000
# 7         (1304, 1302)              (1300)  0.001263    1.000000
# 8         (1304, 1301)              (1300)  0.002066    1.000000
# 9               (6094)              (6063)  0.001148    1.000000
# 10        (1302, 1303)              (1300)  0.001148    1.000000
# 11        (1304, 1303)              (1300)  0.002755    0.960000
# 12        (1301, 1303)              (1300)  0.001607    0.933333
# 13  (1300, 1301, 1303)              (1304)  0.001492    0.928571
# 14                (43)                (20)  0.001492    0.928571
# 15              (6083)              (6063)  0.001263    0.916667
# 16              (1302)              (1304)  0.001263    0.916667
# 17        (1300, 1302)              (1304)  0.001263    0.916667
# 18              (1302)        (1304, 1300)  0.001263    0.916667
# 19              (1304)              (1300)  0.003788    0.916667
# 20        (1304, 1302)              (1303)  0.001148    0.909091
# 21              (3783)              (3782)  0.001148    0.909091
# 22        (1304, 1302)        (1300, 1303)  0.001148    0.909091
# 23  (1304, 1300, 1302)              (1303)  0.001148    0.909091
# 24              (1303)              (1300)  0.003214    0.903226
# 25             (14594)             (14564)  0.001033    0.900000
# 26              (1865)              (1864)  0.001033    0.900000
# 27             (16896)             (16895)  0.001033    0.900000
# 28        (1301, 1303)        (1304, 1300)  0.001492    0.866667
# 29        (1301, 1303)              (1304)  0.001492    0.866667
# 30        (1300, 1301)              (1304)  0.002066    0.857143
# 31        (1300, 1303)              (1304)  0.002755    0.857143
# 32              (1302)        (1304, 1303)  0.001148    0.833333
# 33             (25614)             (25615)  0.001148    0.833333
# 34              (1302)        (1300, 1303)  0.001148    0.833333
# 35        (1300, 1302)              (1303)  0.001148    0.833333
# 36              (1302)              (1303)  0.001148    0.833333
# 37        (1300, 1302)        (1304, 1303)  0.001148    0.833333
# 38              (1302)  (1304, 1300, 1303)  0.001148    0.833333
# 39             (14564)             (14507)  0.001033    0.818182
# 40             (14564)             (14594)  0.001033    0.818182
# 41              (1303)              (1304)  0.002870    0.806452
#
#               ant_list           cons_list  \
# 0               [1302]              [1300]
# 1               [3782]              [3783]
# 2         [1302, 1303]        [1304, 1300]
# 3   [1300, 1302, 1303]              [1304]
# 4   [1304, 1302, 1303]              [1300]
# 5   [1304, 1301, 1303]              [1300]
# 6         [1302, 1303]              [1304]
# 7         [1304, 1302]              [1300]
# 8         [1304, 1301]              [1300]
# 9               [6094]              [6063]
# 10        [1302, 1303]              [1300]
# 11        [1304, 1303]              [1300]
# 12        [1301, 1303]              [1300]
# 13  [1300, 1301, 1303]              [1304]
# 14                [43]                [20]
# 15              [6083]              [6063]
# 16              [1302]              [1304]
# 17        [1300, 1302]              [1304]
# 18              [1302]        [1304, 1300]
# 19              [1304]              [1300]
# 20        [1304, 1302]              [1303]
# 21              [3783]              [3782]
# 22        [1304, 1302]        [1300, 1303]
# 23  [1304, 1300, 1302]              [1303]
# 24              [1303]              [1300]
# 25             [14594]             [14564]
# 26              [1865]              [1864]
# 27             [16896]             [16895]
# 28        [1301, 1303]        [1304, 1300]
# 29        [1301, 1303]              [1304]
# 30        [1300, 1301]              [1304]
# 31        [1300, 1303]              [1304]
# 32              [1302]        [1304, 1303]
# 33             [25614]             [25615]
# 34              [1302]        [1300, 1303]
# 35        [1300, 1302]              [1303]
# 36              [1302]              [1303]
# 37        [1300, 1302]        [1304, 1303]
# 38              [1302]  [1304, 1300, 1303]
# 39             [14564]             [14507]
# 40             [14564]             [14594]
# 41              [1303]              [1304]
#
#                                          ant_prodName  \
# 0     Dungeons & Dragons Starter Box (D&d Boxed Game)
# 1                   Schleich Dragon Knight with Sword
# 2   [Dungeons & Dragons Starter Box (D&d Boxed Gam...
# 3   [Dungeons & Dragons Player's Handbook (Dungeon...
# 4   [Dungeon Master's Guide (Dungeons & Dragons Co...
# 5   [Dungeon Master's Guide (Dungeons & Dragons Co...
# 6   [Dungeons & Dragons Starter Box (D&d Boxed Gam...
# 7   [Dungeon Master's Guide (Dungeons & Dragons Co...
# 8   [Dungeon Master's Guide (Dungeons & Dragons Co...
# 9   Pack Of 24 Boys Junior Glitter Tattoo Stencils...
# 10  [Dungeons & Dragons Starter Box (D&d Boxed Gam...
# 11  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 12  [nan, Monster Manual A Dungeons & Dragons Core...
# 13  [Dungeons & Dragons Player's Handbook (Dungeon...
# 14  Hornby R8223 00 Gauge Track Extension Pack C H...
# 15  Pack Of 36 Mixed Girls Glitter Tattoo Stencils...
# 16    Dungeons & Dragons Starter Box (D&d Boxed Game)
# 17  [Dungeons & Dragons Player's Handbook (Dungeon...
# 18    Dungeons & Dragons Starter Box (D&d Boxed Game)
# 19  Dungeon Master's Guide (Dungeons & Dragons Cor...
# 20  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 21                 Schleich Griffin Knight with Sword
# 22  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 23  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 24  Monster Manual A Dungeons & Dragons Core Rulebook
# 25  Melissa & Doug Royal Princess Puppet With Deta...
# 26                   Motion Sand Beach Bucket Playset
# 27                                     Starting Chess
# 28  [nan, Monster Manual A Dungeons & Dragons Core...
# 29  [nan, Monster Manual A Dungeons & Dragons Core...
# 30  [Dungeons & Dragons Player's Handbook (Dungeon...
# 31  [Dungeons & Dragons Player's Handbook (Dungeon...
# 32    Dungeons & Dragons Starter Box (D&d Boxed Game)
# 33  Jake and The Never Land Pirates Deluxe Adventu...
# 34    Dungeons & Dragons Starter Box (D&d Boxed Game)
# 35  [Dungeons & Dragons Player's Handbook (Dungeon...
# 36    Dungeons & Dragons Starter Box (D&d Boxed Game)
# 37  [Dungeons & Dragons Player's Handbook (Dungeon...
# 38    Dungeons & Dragons Starter Box (D&d Boxed Game)
# 39  Melissa & Doug Pirate Puppet with Detachable W...
# 40  Melissa & Doug Pirate Puppet with Detachable W...
# 41  Monster Manual A Dungeons & Dragons Core Rulebook
#
#                                          con_prodName
# 0   Dungeons & Dragons Player's Handbook (Dungeons...
# 1                  Schleich Griffin Knight with Sword
# 2   [Dungeon Master's Guide (Dungeons & Dragons Co...
# 3   Dungeon Master's Guide (Dungeons & Dragons Cor...
# 4   Dungeons & Dragons Player's Handbook (Dungeons...
# 5   Dungeons & Dragons Player's Handbook (Dungeons...
# 6   Dungeon Master's Guide (Dungeons & Dragons Cor...
# 7   Dungeons & Dragons Player's Handbook (Dungeons...
# 8   Dungeons & Dragons Player's Handbook (Dungeons...
# 9   Girls 10ml Pot Of Glitter Tattoo Glue - Cosmet...
# 10  Dungeons & Dragons Player's Handbook (Dungeons...
# 11  Dungeons & Dragons Player's Handbook (Dungeons...
# 12  Dungeons & Dragons Player's Handbook (Dungeons...
# 13  Dungeon Master's Guide (Dungeons & Dragons Cor...
# 14  Hornby R8222 00 Gauge Track Extension Pack B H...
# 15  Girls 10ml Pot Of Glitter Tattoo Glue - Cosmet...
# 16  Dungeon Master's Guide (Dungeons & Dragons Cor...
# 17  Dungeon Master's Guide (Dungeons & Dragons Cor...
# 18  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 19  Dungeons & Dragons Player's Handbook (Dungeons...
# 20  Monster Manual A Dungeons & Dragons Core Rulebook
# 21                  Schleich Dragon Knight with Sword
# 22  [Dungeons & Dragons Player's Handbook (Dungeon...
# 23  Monster Manual A Dungeons & Dragons Core Rulebook
# 24  Dungeons & Dragons Player's Handbook (Dungeons...
# 25  Melissa & Doug Pirate Puppet with Detachable W...
# 26                  Motion Sand® 2000g Pack - Natural
# 27                 Chess for Kids How to Play and Win
# 28  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 29  Dungeon Master's Guide (Dungeons & Dragons Cor...
# 30  Dungeon Master's Guide (Dungeons & Dragons Cor...
# 31  Dungeon Master's Guide (Dungeons & Dragons Cor...
# 32  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 33  Jake and The Never Land Pirates Hook's Jolly R...
# 34  [Dungeons & Dragons Player's Handbook (Dungeon...
# 35  Monster Manual A Dungeons & Dragons Core Rulebook
# 36  Monster Manual A Dungeons & Dragons Core Rulebook
# 37  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 38  [Dungeon Master's Guide (Dungeons & Dragons Co...
# 39  Melissa & Doug Deluxe Puppet Theatre (Sturdy N...
# 40  Melissa & Doug Royal Princess Puppet With Deta...
# 41  Dungeon Master's Guide (Dungeons & Dragons Cor...

# %%
# Uncomment if prefer printing it out
"""
for i in range(len(df_rules)):
    print('antecedent: ', df_rules['ant_prodName'][i])
    print('consequent: ', df_rules['con_prodName'][i])
    print('confidence: ', df_rules['confidence'][i])
    print("\n")
"""
# Out:
# antecedent:  Dungeons & Dragons Starter Box (D&d Boxed Game)
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  1.0
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  1.0
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  1.0
#
#
# antecedent:  ["Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  1.0
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  1.0
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  1.0
#
#
# antecedent:  ["Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)", nan]
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  1.0
#
#
# antecedent:  Schleich Dragon Knight with Sword
# consequent:  Schleich Griffin Knight with Sword
# confidence:  1.0
#
#
# antecedent:  Pack Of 24 Boys Junior Glitter Tattoo Stencils - 12 Unique Designs In Each Pack
# consequent:  Girls 10ml Pot Of Glitter Tattoo Glue - Cosmetic Body Art Adhesive.
# confidence:  1.0
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)", nan]
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  1.0
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  ["Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)"]
# confidence:  1.0
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)"]
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  0.9599999999999999
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', nan]
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  0.9333333333333333
#
#
# antecedent:  Hornby R8223 00 Gauge Track Extension Pack C Hornby
# consequent:  Hornby R8222 00 Gauge Track Extension Pack B Hornby
# confidence:  0.9285714285714286
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", nan]
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  0.9285714285714286
#
#
# antecedent:  ["Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  0.9166666666666667
#
#
# antecedent:  Pack Of 36 Mixed Girls Glitter Tattoo Stencils - 36 Unique Designs In Each Pack
# consequent:  Girls 10ml Pot Of Glitter Tattoo Glue - Cosmetic Body Art Adhesive.
# confidence:  0.9166666666666667
#
#
# antecedent:  Dungeons & Dragons Starter Box (D&d Boxed Game)
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  0.9166666666666667
#
#
# antecedent:  Dungeons & Dragons Starter Box (D&d Boxed Game)
# consequent:  ["Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)"]
# confidence:  0.9166666666666667
#
#
# antecedent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  0.9166666666666666
#
#
# antecedent:  ["Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Monster Manual A Dungeons & Dragons Core Rulebook
# confidence:  0.9090909090909092
#
#
# antecedent:  Schleich Griffin Knight with Sword
# consequent:  Schleich Dragon Knight with Sword
# confidence:  0.9090909090909092
#
#
# antecedent:  ["Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Monster Manual A Dungeons & Dragons Core Rulebook
# confidence:  0.9090909090909092
#
#
# antecedent:  ["Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)"]
# confidence:  0.9090909090909092
#
#
# antecedent:  Monster Manual A Dungeons & Dragons Core Rulebook
# consequent:  Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)
# confidence:  0.903225806451613
#
#
# antecedent:  Motion Sand Beach Bucket Playset
# consequent:  Motion Sand® 2000g Pack - Natural
# confidence:  0.9
#
#
# antecedent:  Melissa & Doug Royal Princess Puppet With Detachable Wooden Rod for Animated Gestures
# consequent:  Melissa & Doug Pirate Puppet with Detachable Wooden Rod (Puppets & Puppet Theaters, Animated Gestures, Inspires Creativity, 38.1 cm H x 12.7 cm W x 16.51 cm L)
# confidence:  0.9
#
#
# antecedent:  Starting Chess
# consequent:  Chess for Kids How to Play and Win
# confidence:  0.9
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', nan]
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  0.8666666666666667
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', nan]
# consequent:  ["Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)"]
# confidence:  0.8666666666666667
#
#
# antecedent:  ["Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", nan]
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  0.8571428571428572
#
#
# antecedent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)"]
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  0.8571428571428571
#
#
# antecedent:  ["Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)"]
# confidence:  0.8333333333333334
#
#
# antecedent:  ["Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)", 'Dungeons & Dragons Starter Box (D&d Boxed Game)']
# consequent:  Monster Manual A Dungeons & Dragons Core Rulebook
# confidence:  0.8333333333333334
#
#
# antecedent:  Dungeons & Dragons Starter Box (D&d Boxed Game)
# consequent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)"]
# confidence:  0.8333333333333334
#
#
# antecedent:  Dungeons & Dragons Starter Box (D&d Boxed Game)
# consequent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)"]
# confidence:  0.8333333333333334
#
#
# antecedent:  Jake and The Never Land Pirates Deluxe Adventure Figure Pack
# consequent:  Jake and The Never Land Pirates Hook's Jolly Roger Pirate Ship
# confidence:  0.8333333333333334
#
#
# antecedent:  Dungeons & Dragons Starter Box (D&d Boxed Game)
# consequent:  Monster Manual A Dungeons & Dragons Core Rulebook
# confidence:  0.8333333333333334
#
#
# antecedent:  Dungeons & Dragons Starter Box (D&d Boxed Game)
# consequent:  ['Monster Manual A Dungeons & Dragons Core Rulebook', "Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)", "Dungeons & Dragons Player's Handbook (Dungeons & Dragons Core Rulebooks)"]
# confidence:  0.8333333333333334
#
#
# antecedent:  Melissa & Doug Pirate Puppet with Detachable Wooden Rod (Puppets & Puppet Theaters, Animated Gestures, Inspires Creativity, 38.1 cm H x 12.7 cm W x 16.51 cm L)
# consequent:  Melissa & Doug Royal Princess Puppet With Detachable Wooden Rod for Animated Gestures
# confidence:  0.8181818181818182
#
#
# antecedent:  Melissa & Doug Pirate Puppet with Detachable Wooden Rod (Puppets & Puppet Theaters, Animated Gestures, Inspires Creativity, 38.1 cm H x 12.7 cm W x 16.51 cm L)
# consequent:  Melissa & Doug Deluxe Puppet Theatre (Sturdy Non-Tip Base, Plush Curtains, 132.08 cm H × 45.72 cm W × 62.865 cm L)
# confidence:  0.8181818181818182
#
#
# antecedent:  Monster Manual A Dungeons & Dragons Core Rulebook
# consequent:  Dungeon Master's Guide (Dungeons & Dragons Core Rulebooks)
# confidence:  0.8064516129032259
